# %% [markdown]
# <a href="https://colab.research.google.com/github/SeeBook2022/SeeBook-OCR/blob/main/OCR/OCR_resize_grayscale_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### OCR적용하기 전에 input image의 사이즈를 늘리면 성능에 변화가 있는지 확인해보는 작업

# %%
import cv2
import os
import pandas as pd
import time
import re
import datetime
import io
import numpy as np

# %%
# !pip install --upgrade google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.7/dist-packages (2.38.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (0.17.4)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (2.5.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (1.54.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (3.19.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2.23.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (4.2.4)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (57.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2021.10.8)

# %%
# !pip install google-cloud-vision
# Out:
# Requirement already satisfied: google-cloud-vision in /usr/local/lib/python3.7/dist-packages (2.6.3)
# Requirement already satisfied: proto-plus>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-vision) (1.20.3)
# Requirement already satisfied: google-api-core[grpc]<3.0.0dev,>=1.28.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-vision) (2.5.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (3.19.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (1.54.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (1.35.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (2.23.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (1.44.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (1.44.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (4.8)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (57.4.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-vision) (2.10)

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = '/content/drive/MyDrive/Aiffel_Hakathon/my_google_api_key.json'

# %%
def detect_text(path):
    """Detects text in the file."""
    from google.cloud import vision
    import io
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()
        
    image = vision.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    
    result = ''
    for idx, text in enumerate(texts):
        if idx > 0: result += text.description 
    return result

    # if response.error.message:
    #     raise Exception(
    #         '{}\nFor more info on error messages, check: '
    #         'https://cloud.google.com/apis/design/errors'.format(
    #             response.error.message))

# %%
# 전체 작업 시간 측정하기

start = time.time()

result_list = []
img_dir = '/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/model_test_ver2/OCR_test_resize/test_dataset3_ver2/'

for i in range(100):
    print(f'{i+1} 번째 책:')
    paths = img_dir + f'test_title{i+1}.jpg'
    print(detect_text(paths))
    result_list.append(detect_text(paths))
    print('='*30)

print(time.time() - start)
# Out:
# 1 번째 책:
# 세월이가면
# ==============================
# 2 번째 책:
# 님의침묵
# ==============================
# 3 번째 책:
# 먼후일
# ==============================
# 4 번째 책:
# 아
# ==============================
# 5 번째 책:
# 모모
# ==============================
# 6 번째 책:
# 친국의열쇠
# ==============================
# 7 번째 책:
# 고난이선물이다
# ==============================
# 8 번째 책:
#
# ==============================
# 9 번째 책:
# 오뒷세이아
# ==============================
# 10 번째 책:
# 25시
# ==============================
# 11 번째 책:
# 활
# ==============================
# 12 번째 책:
# 가대비극FI
# ==============================
# 13 번째 책:
# 入]25
# ==============================
# 14 번째 책:
# 원
# ==============================
# 15 번째 책:
# 경
# ==============================
# 16 번째 책:
# 인생을어떻게살면좋겠냐고묻는딸에게
# ==============================
# 17 번째 책:
# 아무도기억하지않았다
# ==============================
# 18 번째 책:
# 있는그대로살아도괜찮아
# ==============================
# 19 번째 책:
# 우물밖여고생
# ==============================
# 20 번째 책:
# 오늘은내인생의첫날이다
# ==============================
# 21 번째 책:
# 에이뭘사랑까지하고그래
# ==============================
# 22 번째 책:
# 울
# ==============================
# 23 번째 책:
# 아이가잠들면서재로숨었다
# ==============================
# 24 번째 책:
# 외모는자존감이다
# ==============================
# 25 번째 책:
# 앞으로좋은일만있을나에게
# ==============================
# 26 번째 책:
# 영원한유산
# ==============================
# 27 번째 책:
# 돈의인문학
# ==============================
# 28 번째 책:
# 가짜자존감권하는사회
# ==============================
# 29 번째 책:
# 그페미니즘은틀렸다
# ==============================
# 30 번째 책:
# 백마탄왕자들은왜그렇게떠돌아다닐까
# ==============================
# 31 번째 책:
# 북유럽신화
# ==============================
# 32 번째 책:
# 미술,과학을탐하다
# ==============================
# 33 번째 책:
# 곁에두고읽는니체
# ==============================
# 34 번째 책:
# 대한민국치킨
# ==============================
# 35 번째 책:
# 인간의혹역사
# ==============================
# 36 번째 책:
# 그림에.마음을놓다
# ==============================
# 37 번째 책:
# 개인주의자선언
# ==============================
# 38 번째 책:
# 과학철학의이해
# ==============================
# 39 번째 책:
# 문명과물질
# ==============================
# 40 번째 책:
#
# ==============================
# 41 번째 책:
# 아주친밀한폭력
# ==============================
# 42 번째 책:
# 인간이라는직업
# ==============================
# 43 번째 책:
# 한눈에꿰뚫는세계지명도감
# ==============================
# 44 번째 책:
# 조선국왕연산군
# ==============================
# 45 번째 책:
# 정조와홍대용생각을겨루다
# ==============================
# 46 번째 책:
# 진실의흑역사K
# ==============================
# 47 번째 책:
# 정치학으로의산책
# ==============================
# 48 번째 책:
# 조선의유토피아십승지를다
# ==============================
# 49 번째 책:
# 「제국의위안부』,지식인을말한다
# ==============================
# 50 번째 책:
# 조선시대살아보기
# ==============================
# 51 번째 책:
# 전율범하다專
# ==============================
# 52 번째 책:
# 열하일기
# ==============================
# 53 번째 책:
# 지금여기의페미니즘×민주주의
# ==============================
# 54 번째 책:
# 위대한공존
# ==============================
# 55 번째 책:
# 진중권의서양미술사
# ==============================
# 56 번째 책:
# 식민지청년이봉창의고배
# ==============================
# 57 번째 책:
# 세계사를바꾼전염병R가지
# ==============================
# 58 번째 책:
# 세계사를바꾼가지약
# ==============================
# 59 번째 책:
# 신문읽기의혁명
# ==============================
# 60 번째 책:
# 세계사를바꾼I3가지식물
# ==============================
# 61 번째 책:
# 흐름이보이는세계사경제공부
# ==============================
# 62 번째 책:
# 세계사를움직인위대한여인들
# ==============================
# 63 번째 책:
# 소크라테스를구출하라
# ==============================
# 64 번째 책:
# 사라진스푼
# ==============================
# 65 번째 책:
# 쏭내관의재미있는궁궐기행2
# ==============================
# 66 번째 책:
# 사랑하지말자
# ==============================
# 67 번째 책:
# 세계사편지
# ==============================
# 68 번째 책:
# 쏭내관의재미있는궁궐기행
# ==============================
# 69 번째 책:
# 디케의눈
# ==============================
# 70 번째 책:
# 생명이란무엇인가
# ==============================
# 71 번째 책:
# 셀링사이언스
# ==============================
# 72 번째 책:
# 신은수학자인가?
# ==============================
# 73 번째 책:
# 물리학은처음인데요
# ==============================
# 74 번째 책:
# 미생물이플라톤을만났을때
# ==============================
# 75 번째 책:
# 물리학자는영화에서과학을본다
# ==============================
# 76 번째 책:
# 문명과수학
# ==============================
# 77 번째 책:
# 원자,인간을완성하다
# ==============================
# 78 번째 책:
# 처재과학자들의숨겨진이야기
# ==============================
# 79 번째 책:
# 빛의물리학
# ==============================
# 80 번째 책:
# 이명현의과학책방
# ==============================
# 81 번째 책:
# 바이러스폭풍의시대
# ==============================
# 82 번째 책:
# 하리아의딸들
# ==============================
# 83 번째 책:
# 수학을빛낸여성들.
# ==============================
# 84 번째 책:
# |섀로운아들란티스
# ==============================
# 85 번째 책:
# 생명과학교과서는살아있다
# ==============================
# 86 번째 책:
# 인간은필요없다
# ==============================
# 87 번째 책:
# TO오는걸
# ==============================
# 88 번째 책:
# 이기적인노
# ==============================
# 89 번째 책:
# 영재들의수학퍼즐1저미있는
# ==============================
# 90 번째 책:
# 8세기수학자들의초상
# ==============================
# 91 번째 책:
# 영재들의수학퍼즐2재미있는
# ==============================
# 92 번째 책:
# 수학,인문으로수를읽다27
# ==============================
# 93 번째 책:
# 인간의위대한스승들
# ==============================
# 94 번째 책:
# 교양인을위한화학사강의WIEMANMITDEMFEUERPHILOSOPHIERT
# ==============================
# 95 번째 책:
# 4차산업혁명의충격
# ==============================
# 96 번째 책:
# 수학세계사를만나다
# ==============================
# 97 번째 책:
# 알고리즘,인생을계산하다
# ==============================
# 98 번째 책:
# 사회적원자
# ==============================
# 99 번째 책:
# 우리는왜개는사랑하고돼지는먹고소는신을까
# ==============================
# 100 번째 책:
# 세비퀴로기는과학자전거
# ==============================
# 193.9743402004242

# %%
# 매 작업마다 시간 측정하기

result_list = []
img_dir = '/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/model_test_ver2/OCR_test_resize/test_dataset3_ver2/'

start = time.time()
start_time = True
for i in range(10):
    print(f'{i+1} 번째 책:')
    paths = img_dir + f'test_title{i+1}.jpg'
    print(detect_text(paths))
    result_list.append(detect_text(paths))
    if start_time:
        print(time.time()-start)
        start_time = False
    else:
        medium = time.time()
        print(time.time() - medium)
    print('='*30)
# Out:
# 1 번째 책:
# 세월이가면
# 1.3195362091064453
# ==============================
# 2 번째 책:
# 님의침묵
# 2.1457672119140625e-06
# ==============================
# 3 번째 책:
# 먼후일
# 2.1457672119140625e-06
# ==============================
# 4 번째 책:
# 아
# 1.9073486328125e-06
# ==============================
# 5 번째 책:
# 모모
# 2.1457672119140625e-06
# ==============================
# 6 번째 책:
# 친국의열쇠
# 2.1457672119140625e-06
# ==============================
# 7 번째 책:
# 고난이선물이다
# 2.86102294921875e-06
# ==============================
# 8 번째 책:
#
# 1.6689300537109375e-06
# ==============================
# 9 번째 책:
# 오뒷세이아
# 2.384185791015625e-06
# ==============================
# 10 번째 책:
# 25시
# 2.1457672119140625e-06
# ==============================

# %%
# 파일이름을 오름차순으로 정렬하는 함수

def file_sorted(files):
    temp = [re.split(r"([0-9]+)", s) for s in files]
    sort = sorted(temp, key = lambda x: (x[0].lower(), int(x[1])))
    
    return [''.join(s) for s in sort]

# %%
# 파일경로를 리스트로 만드는 함수

def make_file_paths(path):
    img_names = os.listdir(path)
    file_names = file_sorted(img_names)
    file_paths = []
    for file_name in file_names:
        file_paths.append(path + file_name)

    return file_paths

# %%
# make_file_paths 실험

img_dir = '/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/model_test_ver2/OCR_test_resize/test_dataset3_ver2/'

file_paths = make_file_paths(img_dir)
file_paths

# %%
# 이미지 resize 실험

from google.colab.patches import cv2_imshow

img = '/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/model_test_ver2/OCR_test_resize/test_dataset3_ver2/test_title1.jpg'


imgfile = cv2.cvtColor(cv2.imread(img), cv2.IMREAD_COLOR)

cv2_imshow(imgfile)

# resize_img = cv2.resize(imgfile, dsize=(0,0), fx = 1.5, fy= 1.5, interpolation=cv2.INTER_AREA)

# cv2_imshow(resize_img)


# with io.open(img, 'rb') as image_file:
#         content = image_file.read()

# content
# Out:
# <PIL.Image.Image image mode=RGB size=163x776 at 0x7F1179392910>

# %%
# numpy 배열을 bytes로 바꾸는 실험 => 실패...

def detect_text2(img):
    """Detects text in the file."""
    from google.cloud import vision
    import io
    client = vision.ImageAnnotatorClient()

    content = img.tobytes()
    image = vision.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    
    result = ''
    for idx, text in enumerate(texts):
        if idx > 0: result += text.description 
    return result

    # if response.error.message:
    #     raise Exception(
    #         '{}\nFor more info on error messages, check: '
    #         'https://cloud.google.com/apis/design/errors'.format(
    #             response.error.message))

# %%
# make_file_paths 작업을 추가하였을 때 시간
start = time.time()
start_time = True

result_list2 = []
img_dir = '/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/model_test_ver2/OCR_test_resize/test_dataset3_ver2/'

file_paths2 = make_file_paths(img_dir)

for i, file_path2 in enumerate(file_paths2[:100]):
    print(f'{i+1} 번째 책:')
    print(detect_text(file_path2))
    result_list2.append(detect_text(file_path2))

    print('='*30)

print(time.time()-start)
# Out:
# 1 번째 책:
# 세월이가면
# ==============================
# 2 번째 책:
# 님의침묵
# ==============================
# 3 번째 책:
# 먼후일
# ==============================
# 4 번째 책:
# 아
# ==============================
# 5 번째 책:
# 모모
# ==============================
# 6 번째 책:
# 친국의열쇠
# ==============================
# 7 번째 책:
# 고난이선물이다
# ==============================
# 8 번째 책:
#
# ==============================
# 9 번째 책:
# 오뒷세이아
# ==============================
# 10 번째 책:
# 25시
# ==============================
# 11 번째 책:
# 활
# ==============================
# 12 번째 책:
# 가대비극FI
# ==============================
# 13 번째 책:
# 入]25
# ==============================
# 14 번째 책:
# 원
# ==============================
# 15 번째 책:
# 경
# ==============================
# 16 번째 책:
# 인생을어떻게살면좋겠냐고묻는딸에게
# ==============================
# 17 번째 책:
# 아무도기억하지않았다
# ==============================
# 18 번째 책:
# 있는그대로살아도괜찮아
# ==============================
# 19 번째 책:
# 우물밖여고생
# ==============================
# 20 번째 책:
# 오늘은내인생의첫날이다
# ==============================
# 21 번째 책:
# 에이뭘사랑까지하고그래
# ==============================
# 22 번째 책:
# 울
# ==============================
# 23 번째 책:
# 아이가잠들면서재로숨었다
# ==============================
# 24 번째 책:
# 외모는자존감이다
# ==============================
# 25 번째 책:
# 앞으로좋은일만있을나에게
# ==============================
# 26 번째 책:
# 영원한유산
# ==============================
# 27 번째 책:
# 돈의인문학
# ==============================
# 28 번째 책:
# 가짜자존감권하는사회
# ==============================
# 29 번째 책:
# 그페미니즘은틀렸다
# ==============================
# 30 번째 책:
# 백마탄왕자들은왜그렇게떠돌아다닐까
# ==============================
# 31 번째 책:
# 북유럽신화
# ==============================
# 32 번째 책:
# 미술,과학을탐하다
# ==============================
# 33 번째 책:
# 곁에두고읽는니체
# ==============================
# 34 번째 책:
# 대한민국치킨
# ==============================
# 35 번째 책:
# 인간의혹역사
# ==============================
# 36 번째 책:
# 그림에.마음을놓다
# ==============================
# 37 번째 책:
# 개인주의자선언
# ==============================
# 38 번째 책:
# 과학철학의이해
# ==============================
# 39 번째 책:
# 문명과물질
# ==============================
# 40 번째 책:
#
# ==============================
# 41 번째 책:
# 아주친밀한폭력
# ==============================
# 42 번째 책:
# 인간이라는직업
# ==============================
# 43 번째 책:
# 한눈에꿰뚫는세계지명도감
# ==============================
# 44 번째 책:
# 조선국왕연산군
# ==============================
# 45 번째 책:
# 정조와홍대용생각을겨루다
# ==============================
# 46 번째 책:
# 진실의흑역사K
# ==============================
# 47 번째 책:
# 정치학으로의산책
# ==============================
# 48 번째 책:
# 조선의유토피아십승지를다
# ==============================
# 49 번째 책:
# 「제국의위안부』,지식인을말한다
# ==============================
# 50 번째 책:
# 조선시대살아보기
# ==============================
# 51 번째 책:
# 전율범하다專
# ==============================
# 52 번째 책:
# 열하일기
# ==============================
# 53 번째 책:
# 지금여기의페미니즘×민주주의
# ==============================
# 54 번째 책:
# 위대한공존
# ==============================
# 55 번째 책:
# 진중권의서양미술사
# ==============================
# 56 번째 책:
# 식민지청년이봉창의고배
# ==============================
# 57 번째 책:
# 세계사를바꾼전염병R가지
# ==============================
# 58 번째 책:
# 세계사를바꾼가지약
# ==============================
# 59 번째 책:
# 신문읽기의혁명
# ==============================
# 60 번째 책:
# 세계사를바꾼I3가지식물
# ==============================
# 61 번째 책:
# 흐름이보이는세계사경제공부
# ==============================
# 62 번째 책:
# 세계사를움직인위대한여인들
# ==============================
# 63 번째 책:
# 소크라테스를구출하라
# ==============================
# 64 번째 책:
# 사라진스푼
# ==============================
# 65 번째 책:
# 쏭내관의재미있는궁궐기행2
# ==============================
# 66 번째 책:
# 사랑하지말자
# ==============================
# 67 번째 책:
# 세계사편지
# ==============================
# 68 번째 책:
# 쏭내관의재미있는궁궐기행
# ==============================
# 69 번째 책:
# 디케의눈
# ==============================
# 70 번째 책:
# 생명이란무엇인가
# ==============================
# 71 번째 책:
# 셀링사이언스
# ==============================
# 72 번째 책:
# 신은수학자인가?
# ==============================
# 73 번째 책:
# 물리학은처음인데요
# ==============================
# 74 번째 책:
# 미생물이플라톤을만났을때
# ==============================
# 75 번째 책:
# 물리학자는영화에서과학을본다
# ==============================
# 76 번째 책:
# 문명과수학
# ==============================
# 77 번째 책:
# 원자,인간을완성하다
# ==============================
# 78 번째 책:
# 처재과학자들의숨겨진이야기
# ==============================
# 79 번째 책:
# 빛의물리학
# ==============================
# 80 번째 책:
# 이명현의과학책방
# ==============================
# 81 번째 책:
# 바이러스폭풍의시대
# ==============================
# 82 번째 책:
# 하리아의딸들
# ==============================
# 83 번째 책:
# 수학을빛낸여성들.
# ==============================
# 84 번째 책:
# |섀로운아들란티스
# ==============================
# 85 번째 책:
# 생명과학교과서는살아있다
# ==============================
# 86 번째 책:
# 인간은필요없다
# ==============================
# 87 번째 책:
# TO오는걸
# ==============================
# 88 번째 책:
# 이기적인노
# ==============================
# 89 번째 책:
# 영재들의수학퍼즐1저미있는
# ==============================
# 90 번째 책:
# 8세기수학자들의초상
# ==============================
# 91 번째 책:
# 영재들의수학퍼즐2재미있는
# ==============================
# 92 번째 책:
# 수학,인문으로수를읽다27
# ==============================
# 93 번째 책:
# 인간의위대한스승들
# ==============================
# 94 번째 책:
# 교양인을위한화학사강의WIEMANMITDEMFEUERPHILOSOPHIERT
# ==============================
# 95 번째 책:
# 4차산업혁명의충격
# ==============================
# 96 번째 책:
# 수학세계사를만나다
# ==============================
# 97 번째 책:
# 알고리즘,인생을계산하다
# ==============================
# 98 번째 책:
# 사회적원자
# ==============================
# 99 번째 책:
# 우리는왜개는사랑하고돼지는먹고소는신을까
# ==============================
# 100 번째 책:
# 세비퀴로기는과학자전거
# ==============================
# 144.74491953849792

# %%
# 이미지 resize 작업(1.5배)을 추가하였을 때 걸리는 시간

start = time.time()

result_list3 = []


img_dir = '/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/model_test_ver2/OCR_test_resize/test_dataset3_ver2/'
save_path = '/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/model_test_ver2/OCR_test_resize/resize_img/'

file_paths3 = make_file_paths(img_dir)

for i, file_path3 in enumerate(file_paths3):
    img = cv2.cvtColor(cv2.imread(file_path3), cv2.IMREAD_COLOR)
    resize_img = cv2.resize(img, dsize=(0,0), fx = 1.5, fy= 1.5, interpolation=cv2.INTER_AREA)
    cv2.imwrite(save_path+'resize_img'+str(i)+'.jpg', resize_img)

resize_file_paths = make_file_paths(save_path)

for i, resize_file in enumerate(resize_file_paths[:100]):
    print(f'{i+1} 번째 책:')
    print(detect_text(resize_file))
    result_list3.append(detect_text(resize_file))

    print('='*30)

print(time.time() - start)
# Out:
# 1 번째 책:
# 세월이가면
# ==============================
# 2 번째 책:
# 님의침묵
# ==============================
# 3 번째 책:
# 일먼후
# ==============================
# 4 번째 책:
# 아일리。
# ==============================
# 5 번째 책:
# 모모
# ==============================
# 6 번째 책:
# 천국의열쇠
# ==============================
# 7 번째 책:
# 고난이선물이다
# ==============================
# 8 번째 책:
#
# ==============================
# 9 번째 책:
# 오뒷세이야
# ==============================
# 10 번째 책:
# 25시
# ==============================
# 11 번째 책:
# 부활
# ==============================
# 12 번째 책:
# 대비극
# ==============================
# 13 번째 책:
# 25시
# ==============================
# 14 번째 책:
# 실낙원
# ==============================
# 15 번째 책:
# 경
# ==============================
# 16 번째 책:
# 인생을어떻게살면좋겠냐고묻는딸에게
# ==============================
# 17 번째 책:
# 아무도기억하지않았다
# ==============================
# 18 번째 책:
# 있는그대로-살아도괜찮아
# ==============================
# 19 번째 책:
# 우물밖고생
# ==============================
# 20 번째 책:
# 오늘은내인생의첫날이다
# ==============================
# 21 번째 책:
# 에이뭘사랑까지하고그래
# ==============================
# 22 번째 책:
# 울림
# ==============================
# 23 번째 책:
# 아이가잠들면서재로숨었다
# ==============================
# 24 번째 책:
# 외모는자존감이다
# ==============================
# 25 번째 책:
# 앞으로좋은일만있을나에게
# ==============================
# 26 번째 책:
# 영원한유산
# ==============================
# 27 번째 책:
# 돈의인문학
# ==============================
# 28 번째 책:
# 가짜자존감권하는사회
# ==============================
# 29 번째 책:
# 그페미니즘은틀렸다
# ==============================
# 30 번째 책:
# 백마탄왕자들은왜그렇게떠돌아다닐까
# ==============================
# 31 번째 책:
# 북유럽신화
# ==============================
# 32 번째 책:
# 미술,과학을탐하다
# ==============================
# 33 번째 책:
# 곁에두고읽는니체
# ==============================
# 34 번째 책:
# 대한민국치킨푯
# ==============================
# 35 번째 책:
# 인간의목역사
# ==============================
# 36 번째 책:
# 그림에.마음을놓다
# ==============================
# 37 번째 책:
# 개인주의자선언
# ==============================
# 38 번째 책:
# 과학철학의이해
# ==============================
# 39 번째 책:
# 문명과물질
# ==============================
# 40 번째 책:
#
# ==============================
# 41 번째 책:
# 아주친밀한폭력
# ==============================
# 42 번째 책:
# 인간이라는직업
# ==============================
# 43 번째 책:
# 한눈에꿰뚫는세계지명도감
# ==============================
# 44 번째 책:
# 조선국왕연산군
# ==============================
# 45 번째 책:
# 정조와홍대용생각을겨루다
# ==============================
# 46 번째 책:
# 진실의흑역사
# ==============================
# 47 번째 책:
# 정치학으로의산책
# ==============================
# 48 번째 책:
# 조선의유로피아십승지를다
# ==============================
# 49 번째 책:
# 『제국의위안부』」,지식인을말한다
# ==============================
# 50 번째 책:
# 조선시대살아보기
# ==============================
# 51 번째 책:
# 전율범하다.傳
# ==============================
# 52 번째 책:
# 열하일기
# ==============================
# 53 번째 책:
# 지금여기의페미니즘×민주주의
# ==============================
# 54 번째 책:
# 위대한공존
# ==============================
# 55 번째 책:
# 진중권의서양미술사
# ==============================
# 56 번째 책:
# 식민지청년이봉창의고백
# ==============================
# 57 번째 책:
# 세계사를바꾼전염병R가지
# ==============================
# 58 번째 책:
# 세계사를바꾼가지약
# ==============================
# 59 번째 책:
# 신문읽기의혁명
# ==============================
# 60 번째 책:
# 세계사를바꾼B가지식물
# ==============================
# 61 번째 책:
# 흐름이보이는세계사경제공부
# ==============================
# 62 번째 책:
# 세계사를움직인위대한여인들
# ==============================
# 63 번째 책:
# 소크라테스를구출하라
# ==============================
# 64 번째 책:
# 사라진스푼
# ==============================
# 65 번째 책:
# 쏭내관의재미있는궁궐기행2
# ==============================
# 66 번째 책:
# 하지말자사랑
# ==============================
# 67 번째 책:
# 세계사편지
# ==============================
# 68 번째 책:
# 쏭내관의재미있는궁궐기행
# ==============================
# 69 번째 책:
# 디케의눈
# ==============================
# 70 번째 책:
# 생명이란무엇인가
# ==============================
# 71 번째 책:
# 사셀링이언스
# ==============================
# 72 번째 책:
# 신은수학자인가?
# ==============================
# 73 번째 책:
# 물리학은처음인데요
# ==============================
# 74 번째 책:
# 미생물이플라톤을만났을때
# ==============================
# 75 번째 책:
# 물리학자는영화에서과학을본다
# ==============================
# 76 번째 책:
# 문명과수학
# ==============================
# 77 번째 책:
# 원자,인간을완성하다
# ==============================
# 78 번째 책:
# 처재과학자들의숨겨진이야기
# ==============================
# 79 번째 책:
# 빛의물리학
# ==============================
# 80 번째 책:
# 이명현의과학책방
# ==============================
# 81 번째 책:
# 바이러스폭풍의시대
# ==============================
# 82 번째 책:
# 이감리아의딸들
# ==============================
# 83 번째 책:
# 수학을빛낸여성들.
# ==============================
# 84 번째 책:
# |새로운아들란티스
# ==============================
# 85 번째 책:
# 생명과학교과서는살아있다
# ==============================
# 86 번째 책:
# 인간은필요없다
# ==============================
# 87 번째 책:
# 오H버스는한개번에오는격기가
# ==============================
# 88 번째 책:
# 이기적인뇌노
# ==============================
# 89 번째 책:
# 영재들의수학퍼즐1저미있는IL
# ==============================
# 90 번째 책:
# 8세기수학자들의초상
# ==============================
# 91 번째 책:
# 영재들의수학퍼즐2IL재미있는
# ==============================
# 92 번째 책:
# 수학,인문으로수를읽다스르이다227
# ==============================
# 93 번째 책:
# 인간의위대한스승들
# ==============================
# 94 번째 책:
# 교양인을위한화학사강의WIEMANMITDEMFEUERPHILOSOPHIERT
# ==============================
# 95 번째 책:
# 4차산업혁명의충격:
# ==============================
# 96 번째 책:
# 수학세계사를만나다
# ==============================
# 97 번째 책:
# 알고리즘,인생을계산하다
# ==============================
# 98 번째 책:
# 사회적원자
# ==============================
# 99 번째 책:
# 우리는왜개는사랑하고돼지는먹고소는신을까
# ==============================
# 100 번째 책:
# 세비퀴로가는과학자전거
# ==============================
# 153.77567100524902

# %%
# 흑백이미지로 변환 후 ocr까지 시간측정

start = time.time()

result_list4 = []


img_dir = '/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/model_test_ver2/OCR_test_resize/test_dataset3_ver2/'
save_path2 = '/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/model_test_ver2/OCR_test_resize/grayscale_img/'

file_paths4 = make_file_paths(img_dir)

for i, file_path4 in enumerate(file_paths4):
    gray_img = cv2.imread(file_path4, cv2.IMREAD_GRAYSCALE)
    cv2.imwrite(save_path+'gray_img'+str(i)+'.jpg', gray_img)

gray_paths = make_file_paths(save_path2)

for i, gray_file in enumerate(gray_paths[:100]):
    print(f'{i+1} 번째 책:')
    print(detect_text(gray_file))
    result_list4.append(detect_text(gray_file))

    print('='*30)

print(time.time() - start)
# Out:
# 1 번째 책:
# 세월이가면
# ==============================
# 2 번째 책:
# 님의침묵
# ==============================
# 3 번째 책:
# 먼후일
# ==============================
# 4 번째 책:
# 아
# ==============================
# 5 번째 책:
# 모모
# ==============================
# 6 번째 책:
# 친국의열쇠
# ==============================
# 7 번째 책:
# 고난이선물이다
# ==============================
# 8 번째 책:
#
# ==============================
# 9 번째 책:
# 오뒷세이아
# ==============================
# 10 번째 책:
# 25시
# ==============================
# 11 번째 책:
# 활
# ==============================
# 12 번째 책:
# 가대비극FI
# ==============================
# 13 번째 책:
# 2.시
# ==============================
# 14 번째 책:
# 원
# ==============================
# 15 번째 책:
# 경
# ==============================
# 16 번째 책:
# 인생을어떻게살면좋겠냐고묻는딸에게
# ==============================
# 17 번째 책:
# 아무도기억하지않았다
# ==============================
# 18 번째 책:
# 있는그대로살아도괜찮아
# ==============================
# 19 번째 책:
# 우물밖여고생
# ==============================
# 20 번째 책:
# 오늘은내인생의첫날이다
# ==============================
# 21 번째 책:
# 에이뭘사랑까지하고그래
# ==============================
# 22 번째 책:
# 울
# ==============================
# 23 번째 책:
# 아이가잠들면서재로숨었다
# ==============================
# 24 번째 책:
# 외모는자존감이다
# ==============================
# 25 번째 책:
# 앞으로좋은일만있을나에게
# ==============================
# 26 번째 책:
# 한영원히유산TO
# ==============================
# 27 번째 책:
# 돈의인문학
# ==============================
# 28 번째 책:
# 가짜자존감권하는사회
# ==============================
# 29 번째 책:
# 그페미니즘은틀렸다
# ==============================
# 30 번째 책:
# 백마탄왕자들은왜그렇게떠돌아다닐까
# ==============================
# 31 번째 책:
# 북유럽신화
# ==============================
# 32 번째 책:
# 미술,과학을탐하다
# ==============================
# 33 번째 책:
# 곁에두고읽는니체
# ==============================
# 34 번째 책:
# 대한민국치킨
# ==============================
# 35 번째 책:
# 인간의혹역사
# ==============================
# 36 번째 책:
# 그림에.마음을놓다
# ==============================
# 37 번째 책:
# 개인주의자선언
# ==============================
# 38 번째 책:
# 과학철학의이해
# ==============================
# 39 번째 책:
# 문명과물질
# ==============================
# 40 번째 책:
#
# ==============================
# 41 번째 책:
# 아주친밀한폭력
# ==============================
# 42 번째 책:
# 인간이라는직업
# ==============================
# 43 번째 책:
# 한눈에꿰뚫는세계지명도감
# ==============================
# 44 번째 책:
# 조선국왕연산군
# ==============================
# 45 번째 책:
# 정조와홍대용생각을겨루다
# ==============================
# 46 번째 책:
# 진실의흑역사
# ==============================
# 47 번째 책:
# 정치학으로의산책
# ==============================
# 48 번째 책:
# 조선의유토피아십승지를김다
# ==============================
# 49 번째 책:
# 「제국의위안부」,지식인을말한다
# ==============================
# 50 번째 책:
# 조선시대살아보기
# ==============================
# 51 번째 책:
# 전울범하다專
# ==============================
# 52 번째 책:
# 열하일기
# ==============================
# 53 번째 책:
# 지금여기의페미니즘×민주주의
# ==============================
# 54 번째 책:
# 위대한공존
# ==============================
# 55 번째 책:
# 진중권의서양미술사
# ==============================
# 56 번째 책:
# 식민지청년이봉창의고배
# ==============================
# 57 번째 책:
# 세계사를바꾼전염병R가지
# ==============================
# 58 번째 책:
# 세계사를바꾼가지약
# ==============================
# 59 번째 책:
# 신문읽기의혁명
# ==============================
# 60 번째 책:
# 세계사를바꾼K가지식물
# ==============================
# 61 번째 책:
# 흐름이보이는세계사경제공부
# ==============================
# 62 번째 책:
# 세계사를움직인위대한여인들
# ==============================
# 63 번째 책:
# 소크라테스를구출하라
# ==============================
# 64 번째 책:
# 사라진스푼
# ==============================
# 65 번째 책:
# 쏭내관의재미있는궁궐기행2
# ==============================
# 66 번째 책:
# 사랑하지말자
# ==============================
# 67 번째 책:
# 세계사편지
# ==============================
# 68 번째 책:
# 쏭내관의재미있는궁궐기행
# ==============================
# 69 번째 책:
# 디케의눈
# ==============================
# 70 번째 책:
# 생명이란무엇인가
# ==============================
# 71 번째 책:
# 셀링사이언스
# ==============================
# 72 번째 책:
# 신은수학자인가?
# ==============================
# 73 번째 책:
# 물리학은처음인데요
# ==============================
# 74 번째 책:
# 미생물이플라톤을만났을때
# ==============================
# 75 번째 책:
# 물리학자는영화에서과학을본다
# ==============================
# 76 번째 책:
# 문명과수학
# ==============================
# 77 번째 책:
# 원자,인간을완성하다
# ==============================
# 78 번째 책:
# 처재과학자들의숨겨진이야기
# ==============================
# 79 번째 책:
# 빛의물리학
# ==============================
# 80 번째 책:
# 이명현의과학책방
# ==============================
# 81 번째 책:
# 바이러스폭풍의시대
# ==============================
# 82 번째 책:
# 아리아의딸들
# ==============================
# 83 번째 책:
# 수학을빛낸여성들.
# ==============================
# 84 번째 책:
# |섀로운아들란티스
# ==============================
# 85 번째 책:
# 생명과학교과서는살아있다
# ==============================
# 86 번째 책:
# 인간은필요없다YE
# ==============================
# 87 번째 책:
# 오버스는한계번에오는.
# ==============================
# 88 번째 책:
# 이기적인노
# ==============================
# 89 번째 책:
# 영재들의수학퍼즐1저미있는
# ==============================
# 90 번째 책:
# 8세기수학자들의초상
# ==============================
# 91 번째 책:
# 영재들의수학퍼즐2재미있는
# ==============================
# 92 번째 책:
# 수학,인문으로수를읽다20CH27
# ==============================
# 93 번째 책:
# 인간의위대한스승들
# ==============================
# 94 번째 책:
# 교양인을위한화학사강의WIEMANMITDEMFEUERPHILOSOPHIERT
# ==============================
# 95 번째 책:
# 4차산업혁명의충격
# ==============================
# 96 번째 책:
# 수학세계사를만나다
# ==============================
# 97 번째 책:
# 알고리즘,인생을계산하다
# ==============================
# 98 번째 책:
# 사회적원자
# ==============================
# 99 번째 책:
# 우리는왜개는사랑하고돼지는먹고소는신을까
# ==============================
# 100 번째 책:
# 세비퀴로기는과학자전거
# ==============================
# 150.57425355911255

# %%
# 이미지 resize 작업(2배)을 추가하였을 때 걸리는 시간

start = time.time()

result_list5 = []


img_dir = '/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/model_test_ver2/OCR_test_resize/test_dataset3_ver2/'
save_path = '/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/model_test_ver2/OCR_test_resize/resize_img2/'

file_paths4 = make_file_paths(img_dir)

for i, file_path4 in enumerate(file_paths4):
    img2 = cv2.cvtColor(cv2.imread(file_path4), cv2.IMREAD_COLOR)
    resize_img2 = cv2.resize(img2, dsize=(0,0), fx = 2, fy= 2, interpolation=cv2.INTER_AREA)
    cv2.imwrite(save_path+'resize_img'+str(i)+'.jpg', resize_img2)

resize_file_paths2 = make_file_paths(save_path)

for i, resize_file2 in enumerate(resize_file_paths2[:100]):
    print(f'{i+1} 번째 책:')
    print(detect_text(resize_file2))
    result_list5.append(detect_text(resize_file2))

    print('='*30)

print(time.time() - start)
# Out:
# 1 번째 책:
# 세월이가면
# ==============================
# 2 번째 책:
# 님의침묵
# ==============================
# 3 번째 책:
# 먼후일
# ==============================
# 4 번째 책:
# 아
# ==============================
# 5 번째 책:
# 모
# ==============================
# 6 번째 책:
# 친국의열쇠
# ==============================
# 7 번째 책:
# 고난이선물이다
# ==============================
# 8 번째 책:
#
# ==============================
# 9 번째 책:
# 아오뒷세이
# ==============================
# 10 번째 책:
# 25시
# ==============================
# 11 번째 책:
# 활
# ==============================
# 12 번째 책:
# 4대비극
# ==============================
# 13 번째 책:
# 25
# ==============================
# 14 번째 책:
# 원
# ==============================
# 15 번째 책:
# 경
# ==============================
# 16 번째 책:
# 인생을어떻게살면좋겠냐고묻는딸에게
# ==============================
# 17 번째 책:
# 아무도기억하지않았다
# ==============================
# 18 번째 책:
# 있는그대로살아도괜찮아
# ==============================
# 19 번째 책:
# 우물밖여고생
# ==============================
# 20 번째 책:
# 오늘은내인생의첫날이다
# ==============================
# 21 번째 책:
# 에이뭘사랑까지하고그래
# ==============================
# 22 번째 책:
# 울
# ==============================
# 23 번째 책:
# 아이가잠들면서재로숨었다
# ==============================
# 24 번째 책:
# 외모는자존감이다
# ==============================
# 25 번째 책:
# 앞으로좋은일만있을나에게
# ==============================
# 26 번째 책:
# 한영원하TO
# ==============================
# 27 번째 책:
# 돈의인문학
# ==============================
# 28 번째 책:
# 가짜자존감권하는사회
# ==============================
# 29 번째 책:
# 그페미니즘은틀렸다
# ==============================
# 30 번째 책:
# 백마탄왕자들은왜그렇게떠돌아다닐까
# ==============================
# 31 번째 책:
# 북유럽신화
# ==============================
# 32 번째 책:
# 미술,과학을탐하다
# ==============================
# 33 번째 책:
# 곁에두고읽는니체
# ==============================
# 34 번째 책:
# 대한민국치킨R
# ==============================
# 35 번째 책:
# 인간의혹역사
# ==============================
# 36 번째 책:
# 그림에,마음을놓다
# ==============================
# 37 번째 책:
# 개인주의자선언
# ==============================
# 38 번째 책:
# 과학철학의이해
# ==============================
# 39 번째 책:
# 문명과물질
# ==============================
# 40 번째 책:
# に
# ==============================
# 41 번째 책:
# 아주친밀한폭력
# ==============================
# 42 번째 책:
# 인간이라는직업
# ==============================
# 43 번째 책:
# 한눈에꿰뚫는세계지명도감
# ==============================
# 44 번째 책:
# 조선국왕연산군
# ==============================
# 45 번째 책:
# 정조와홍대용생각을겨루다
# ==============================
# 46 번째 책:
# 진실의흑역사K
# ==============================
# 47 번째 책:
# 정치학으로의산책
# ==============================
# 48 번째 책:
# 조선의유토피아십승지를걷다
# ==============================
# 49 번째 책:
# 『제국의위안부』,지식인을말한다
# ==============================
# 50 번째 책:
# 조선시대살아보기
# ==============================
# 51 번째 책:
# 전율범하다專
# ==============================
# 52 번째 책:
# 열하일기
# ==============================
# 53 번째 책:
# 지금여기의페미니즘x민주주의
# ==============================
# 54 번째 책:
# 위대한공존
# ==============================
# 55 번째 책:
# 진중권의서양미술사
# ==============================
# 56 번째 책:
# 식민지청년이봉창의고백
# ==============================
# 57 번째 책:
# 세계사를바꾼전염병R가지
# ==============================
# 58 번째 책:
# 세계사를바꾼가지약
# ==============================
# 59 번째 책:
# 신문읽기의혁명
# ==============================
# 60 번째 책:
# 세계사를바꾼3가지식물
# ==============================
# 61 번째 책:
# 흐름이보이는세계사경제공부
# ==============================
# 62 번째 책:
# 세계사를움직인위대한여인들
# ==============================
# 63 번째 책:
# 소크라테스를구출하라
# ==============================
# 64 번째 책:
# 사진
# ==============================
# 65 번째 책:
# 쏭나관의재미있는궁궐기행2
# ==============================
# 66 번째 책:
# 사랑하지말スト
# ==============================
# 67 번째 책:
# 세계사편지
# ==============================
# 68 번째 책:
# 쏭내관의재미있는궁궐기행
# ==============================
# 69 번째 책:
# 디케의눈
# ==============================
# 70 번째 책:
# 생명이란무엇인가
# ==============================
# 71 번째 책:
# 셀링사이언스
# ==============================
# 72 번째 책:
# 신은수학자인가?
# ==============================
# 73 번째 책:
# 물리학은처음인데요
# ==============================
# 74 번째 책:
# 미생물이플라톤을만났을때
# ==============================
# 75 번째 책:
# 물리학자는영화에서과학을본다
# ==============================
# 76 번째 책:
# 문명과수학
# ==============================
# 77 번째 책:
# 원자,인간을완성하다
# ==============================
# 78 번째 책:
# 처재과학자들의숨겨진이야기
# ==============================
# 79 번째 책:
# 빛의물리학
# ==============================
# 80 번째 책:
# 이명현의과학책방
# ==============================
# 81 번째 책:
# 바이러스폭풍의시대
# ==============================
# 82 번째 책:
# 이감리아의딸들
# ==============================
# 83 번째 책:
# 수학을빚낸여성들.
# ==============================
# 84 번째 책:
# |새로운아들란티스
# ==============================
# 85 번째 책:
# 생명과학교과서는살아있다
# ==============================
# 86 번째 책:
# 인간은필요없다YE
# ==============================
# 87 번째 책:
# 오HB스는한계번에오는적
# ==============================
# 88 번째 책:
# 이기적인노
# ==============================
# 89 번째 책:
# 영재들의수학퍼즐1
# ==============================
# 90 번째 책:
# 8세기수학자들의초상
# ==============================
# 91 번째 책:
# 영재들의수학퍼즐2재미있는IL
# ==============================
# 92 번째 책:
# 수학,인문으로수를읽다20CH27
# ==============================
# 93 번째 책:
# 인간의위대한스승들
# ==============================
# 94 번째 책:
# 화학사강의교양인을위한WIEMANMITDEMFEUERPHILOSOPHIERT
# ==============================
# 95 번째 책:
# 4차산업혁명의충격
# ==============================
# 96 번째 책:
# 수학세계사를만나다
# ==============================
# 97 번째 책:
# 알고리즘.인생을계산하다
# ==============================
# 98 번째 책:
# 사회적원자
# ==============================
# 99 번째 책:
# 우리는왜개는사랑하고돼지는먹고소는신을까
# ==============================
# 100 번째 책:
# 세비퀴로기는과학자전거
# ==============================
# 157.52393054962158

# %%
# 데이터 프레임으로 만들기

df = pd.read_csv('/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/test_dataset3_title.csv', encoding = 'UTF-8')
df1 = df.copy()
df1
# Out:
#                   파일명                          책제목
# 0     test_title1.jpg                       세월이 가면
# 1     test_title2.jpg                        님의 침묵
# 2     test_title3.jpg                         먼 후일
# 3     test_title4.jpg                         일리아스
# 4     test_title5.jpg                           모모
# ..                ...                          ...
# 95   test_title96.jpg                 수학, 세계사를 만나다
# 96   test_title97.jpg               알고리즘, 인생을 계산하다
# 97   test_title98.jpg                       사회적 원자
# 98   test_title99.jpg  우리는 왜 개는 사랑하고 돼지는 먹고 소는 신을까
# 99  test_title100.jpg                세바퀴로 가는 과학자전거
#
# [100 rows x 2 columns]

# %%
df1['result'] = result_list
df1['result_resize'] = result_list3
df1['result_gray'] = result_list4
df1['result_resize2'] = result_list5

# %%
df1
# Out:
#                   파일명  ...        result_resize2
# 0     test_title1.jpg  ...                 세월이가면
# 1     test_title2.jpg  ...                  님의침묵
# 2     test_title3.jpg  ...                   먼후일
# 3     test_title4.jpg  ...                     아
# 4     test_title5.jpg  ...                     모
# ..                ...  ...                   ...
# 95   test_title96.jpg  ...             수학세계사를만나다
# 96   test_title97.jpg  ...          알고리즘.인생을계산하다
# 97   test_title98.jpg  ...                 사회적원자
# 98   test_title99.jpg  ...  우리는왜개는사랑하고돼지는먹고소는신을까
# 99  test_title100.jpg  ...           세비퀴로기는과학자전거
#
# [100 rows x 6 columns]

# %%
def preprocess_sentence(sentence):
    import re
    # (a-z, A-Z, ㄱ-ㅎ, ㅏ-ㅣ, 가-힣)를 제외한 모든 문자를 공백인 ' '로 대체
    # sentence = re.sub(r"[^a-zA-Zㄱ-ㅣ가-힣0-9]+", " ", sentence)
    sentence = re.sub('[-=+,「#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]','', sentence)
    sentence = sentence.replace(' ', '') # 공백 제거
    sentence = sentence.strip()
    return sentence

# %%
for idx, sentence in enumerate(df1['책제목']):
    df1['책제목'][idx] = preprocess_sentence(sentence)
for idx, sentence in enumerate(df1['result']):
    df1['result'][idx] = preprocess_sentence(sentence)
for idx, sentence in enumerate(df1['result_resize']):
    df1['result_resize'][idx] = preprocess_sentence(sentence)
for idx, sentence in enumerate(df1['result_gray']):
    df1['result_gray'][idx] = preprocess_sentence(sentence)
for idx, sentence in enumerate(df1['result_resize2']):
    df1['result_resize2'][idx] = preprocess_sentence(sentence)

# %%
# 1차 검증
val_list = []
for i, sentence in enumerate(df1['result']):
    if sentence == '':
        val_list.append('0%')
    elif sentence == df1['책제목'][i]:
        val_list.append('100%')
    else:
        val_list.append('Fail')
print(val_list)
# Out:
# ['100%', '100%', '100%', 'Fail', '100%', 'Fail', '100%', '0%', '100%', '100%', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', 'Fail', '100%', '100%', '100%', '100%', '0%', '100%', '100%', '100%', '100%', '100%', 'Fail', '100%', 'Fail', '100%', '100%', 'Fail', '100%', 'Fail', '100%', '100%', 'Fail', 'Fail', 'Fail', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', 'Fail', '100%', 'Fail', '100%', '100%', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', 'Fail']

# %%
val_list2 = []
for i, sentence in enumerate(df1['result_resize']):
    if sentence == '':
        val_list2.append('0%')
    elif sentence == df1['책제목'][i]:
        val_list2.append('100%')
    else:
        val_list2.append('Fail')
print(val_list2)
# Out:
# ['100%', '100%', 'Fail', 'Fail', '100%', '100%', '100%', '0%', 'Fail', '100%', '100%', 'Fail', '100%', '100%', 'Fail', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', 'Fail', '100%', '100%', '100%', '100%', '0%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', 'Fail', '100%', 'Fail', '100%', 'Fail', '100%', '100%', '100%', 'Fail', 'Fail', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', 'Fail', '100%', 'Fail', '100%', '100%', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', 'Fail']

# %%
val_list3 = []
for i, sentence in enumerate(df1['result_gray']):
    if sentence == '':
        val_list3.append('0%')
    elif sentence == df1['책제목'][i]:
        val_list3.append('100%')
    else:
        val_list3.append('Fail')
print(val_list3)
# Out:
# ['100%', '100%', '100%', 'Fail', '100%', 'Fail', '100%', '0%', '100%', '100%', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', 'Fail', '100%', '100%', '100%', '100%', '0%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', 'Fail', '100%', 'Fail', '100%', 'Fail', '100%', '100%', 'Fail', 'Fail', 'Fail', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', 'Fail', '100%', 'Fail', '100%', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', 'Fail']

# %%
val_list4 = []
for i, sentence in enumerate(df1['result_resize2']):
    if sentence == '':
        val_list4.append('0%')
    elif sentence == df1['책제목'][i]:
        val_list4.append('100%')
    else:
        val_list4.append('Fail')
print(val_list4)
# Out:
# ['100%', '100%', '100%', 'Fail', 'Fail', 'Fail', '100%', '0%', 'Fail', '100%', 'Fail', '100%', 'Fail', 'Fail', 'Fail', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', 'Fail', '100%', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', 'Fail', '100%', '100%', 'Fail', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', 'Fail', 'Fail', '100%', 'Fail', '100%', '100%', '100%', 'Fail', 'Fail', 'Fail', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', '100%', 'Fail', '100%', '100%', '100%', 'Fail', 'Fail', 'Fail', '100%', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', '100%', 'Fail', '100%', '100%', '100%', '100%', '100%', 'Fail']

# %%
df1['compare1'] = val_list
df1['compare2'] = val_list2
df1['compare3'] = val_list3
df1['compare4'] = val_list4

# %%
df1
# Out:
#                   파일명                   책제목  ... compare3 compare4
# 0     test_title1.jpg                 세월이가면  ...     100%     100%
# 1     test_title2.jpg                  님의침묵  ...     100%     100%
# 2     test_title3.jpg                   먼후일  ...     100%     100%
# 3     test_title4.jpg                  일리아스  ...     Fail     Fail
# 4     test_title5.jpg                    모모  ...     100%     Fail
# ..                ...                   ...  ...      ...      ...
# 95   test_title96.jpg             수학세계사를만나다  ...     100%     100%
# 96   test_title97.jpg           알고리즘인생을계산하다  ...     100%     100%
# 97   test_title98.jpg                 사회적원자  ...     100%     100%
# 98   test_title99.jpg  우리는왜개는사랑하고돼지는먹고소는신을까  ...     100%     100%
# 99  test_title100.jpg           세바퀴로가는과학자전거  ...     Fail     Fail
#
# [100 rows x 10 columns]

# %%
print(df1['compare1'].value_counts())
print(df1['compare2'].value_counts())
print(df1['compare3'].value_counts())
print(df1['compare4'].value_counts())
# Out:
# 100%    69
# Fail    29
# 0%       2
# Name: compare1, dtype: int64
# 100%    70
# Fail    28
# 0%       2
# Name: compare2, dtype: int64
# 100%    67
# Fail    31
# 0%       2
# Name: compare3, dtype: int64
# 100%    64
# Fail    35
# 0%       1
# Name: compare4, dtype: int64
