# %% [markdown]
# <a href="https://colab.research.google.com/github/SeeBook2022/SeeBook-OCR/blob/main/detection/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10876, done.
# remote: Total 10876 (delta 0), reused 0 (delta 0), pack-reused 10876
# Receiving objects: 100% (10876/10876), 10.98 MiB | 26.63 MiB/s, done.
# Resolving deltas: 100% (7515/7515), done.

# %%
# !cd yolov5;pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 596 kB 11.7 MB/s

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive

# %%
# !ls /mydrive
# Out:
# /mydrive

# %%
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 11.8 MB/s
# ...
#      |████████████████████████████████| 180 kB 46.1 MB/s
# ...
#      |████████████████████████████████| 144 kB 48.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.8 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=a4b26d9ac17db21659d75a533a56738f94c5b82c1cb4677fd793aa8c289f4481
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# ...

# %%
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import wandb

wandb.init(project="book_detection", entity="eugene2709")
# Out:
# wandb: Currently logged in as: eugene2709 (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/eugene2709/book_detection/runs/u4fi5vay" target="_blank">kind-flower-3</a></strong> to <a href="https://wandb.ai/eugene2709/book_detection" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/eugene2709/book_detection/runs/u4fi5vay?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
# epochs = 30
# train image 199개
# validation image 17개

# !cd /content/yolov5; python train.py --img 640 --batch 16 --epochs 70 --data /content/drive/MyDrive/aiffel_hackathon/trainNvalid/book_spine.yaml --weights yolov5m.pt \
                                     --project=/content/drive/MyDrive/aiffel_hackathon/model --name epoch70_batch16 --exist-ok
# Out:
# ...
# wandb: Currently logged in as: eugene2709 (use `wandb login --relogin` to force relogin)
# train: weights=yolov5m.pt, cfg=, data=/content/drive/MyDrive/aiffel_hackathon/trainNvalid/book_spine.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=70, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/content/drive/MyDrive/aiffel_hackathon/model, name=epoch70_batch16, exist_ok=True, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-255-gca0a007 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# epochs = 30
# train image 199개
# validation image 17개

# !cd /content/yolov5; python train.py --img 640 --batch 8 --epochs 130 --data /content/drive/MyDrive/aiffel_hackathon/trainNvalid/book_spine.yaml --weights yolov5m.pt \
                                     --project=/content/drive/MyDrive/aiffel_hackathon/model --name epoch130 --exist-ok
# Out:
# wandb: Currently logged in as: eugene2709 (use `wandb login --relogin` to force relogin)
# train: weights=yolov5m.pt, cfg=, data=/content/drive/MyDrive/aiffel_hackathon/trainNvalid/book_spine.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=130, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/content/drive/MyDrive/aiffel_hackathon/model, name=epoch130, exist_ok=True, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-253-ga45e472 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...
