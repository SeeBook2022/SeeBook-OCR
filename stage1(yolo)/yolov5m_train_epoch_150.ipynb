# %% [markdown]
# <a href="https://colab.research.google.com/github/SeeBook2022/SeeBook-OCR/blob/main/stage1(yolo)/yolov5m_train_epoch_150.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10941, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 10941 (delta 0), reused 4 (delta 0), pack-reused 10934
# Receiving objects: 100% (10941/10941), 11.04 MiB | 29.90 MiB/s, done.
# Resolving deltas: 100% (7556/7556), done.

# %%
# !cd yolov5;pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 596 kB 5.4 MB/s
#      |████████████████████████████████| 1.7 MB 52.2 MB/s
#      |████████████████████████████████| 181 kB 64.9 MB/s
#      |████████████████████████████████| 144 kB 61.3 MB/s
#      |████████████████████████████████| 63 kB 2.1 MB/s
# ...

# %%
# !cd /content/yolov5; python train.py --img 640 --batch 16 --epochs 150 --data /content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/train_dataset1_ver2/stage1.yaml --weights yolov5m.pt \
                                     --project=/content/drive/MyDrive/Aiffel_Hakathon/3rd_hackathon/train_dataset1_ver2 --name book --exist-ok
# Out:
# ...
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 2
# wandb: You chose 'Use an existing W&B account'
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...

# %%
import wandb
wandb.init(project="train_dataset1_ver2", entity="seebook_ocr")
# Out:
# wandb: Currently logged in as: seebook_ocr (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/seebook_ocr/train_dataset1_ver2/runs/1vm7yxz5" target="_blank">jumping-sky-1</a></strong> to <a href="https://wandb.ai/seebook_ocr/train_dataset1_ver2" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/seebook_ocr/train_dataset1_ver2/runs/1vm7yxz5?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>
