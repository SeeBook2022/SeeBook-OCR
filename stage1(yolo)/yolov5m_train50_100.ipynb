# %% [markdown]
# <a href="https://colab.research.google.com/github/SeeBook2022/SeeBook-OCR/blob/main/stage1(yolo)/yolov5m_train50_100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10941, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 10941 (delta 0), reused 5 (delta 0), pack-reused 10934
# Receiving objects: 100% (10941/10941), 11.08 MiB | 19.57 MiB/s, done.
# Resolving deltas: 100% (7551/7551), done.

# %%
# !cd yolov5;pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 596 kB 8.6 MB/s

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive

# %%
# !ls /mydrive
# Out:
# /mydrive

# %%
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 8.8 MB/s
# ...
#      |████████████████████████████████| 144 kB 49.0 MB/s
# ...
#      |████████████████████████████████| 181 kB 10.8 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=3f3e67b4d76b7aeffba8568551df59f0d72e9d3ed2477ced13f56cfbd800de3c
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# ...

# %%
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import wandb

wandb.init(project="Seebook-OCR", entity="yeonkkk")
# Out:
# wandb: Currently logged in as: yeonkkk (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/yeonkkk/Seebook-OCR/runs/c7ws44wf" target="_blank">misunderstood-spaceship-1</a></strong> to <a href="https://wandb.ai/yeonkkk/Seebook-OCR" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/yeonkkk/Seebook-OCR/runs/c7ws44wf?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# %pwd
# Out:
# '/content/yolov5'

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data "/content/yolov5/data/stage1.yaml" --weights yolov5m.pt --project '/content/drive/MyDrive/aiffel_hackathon3' --name epoch50_batch16
# Out:
# wandb: Currently logged in as: yeonkkk (use `wandb login --relogin` to force relogin)
# train: weights=yolov5m.pt, cfg=, data=/content/yolov5/data/stage1.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/content/drive/MyDrive/aiffel_hackathon3, name=epoch50_batch16, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-276-ga936f5f torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data "/content/yolov5/data/stage1.yaml" --weights yolov5m.pt --cache --project '/content/drive/MyDrive/aiffel_hackathon3' --name epoch100_batch16
# Out:
# wandb: Currently logged in as: yeonkkk (use `wandb login --relogin` to force relogin)
# train: weights=yolov5m.pt, cfg=, data=/content/yolov5/data/stage1.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/content/drive/MyDrive/aiffel_hackathon3, name=epoch100_batch16, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-276-ga936f5f torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...
